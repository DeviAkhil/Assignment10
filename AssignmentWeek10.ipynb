# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1. Read the data into python

# %%
data = pd.read_csv(r'D:\Devi\ICT_TVM\ASSIGNMENTS\week10.csv')

# %%
data.head()
# Out:
#           ph    Hardness       Solids  Chloramines     Sulfate  Conductivity  \
# 0   8.316766  214.373394  22018.41744     8.059332  356.886136    363.266516
# 1   9.092223  181.101509  17978.98634     6.546600  310.135738    398.410813
# 2   5.584087  188.313324  28748.68774     7.544869  326.678363    280.467916
# 3  10.223862  248.071735  28749.71654     7.513408  393.663395    283.651634
# 4   8.635849  203.361523  13672.09176     4.563009  303.309771    474.607645
#
#    Organic_carbon  Trihalomethanes  Turbidity
# 0       18.436525       100.341674   4.628771
# 1       11.558279        31.997993   4.075075
# 2        8.399735        54.917862   2.559708
# 3       13.789695        84.603556   2.672989
# 4       12.363817        62.798309   4.401425

# %% [markdown]
# ### 2. Check for null values

# %%
data.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# dtype: int64

# %%
sns.heatmap(data.isna(),yticklabels=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is no null values present in the dataset

# %%
data.shape
# Out:
# (2011, 9)

# %%
data.dtypes
# Out:
# ph                 float64
# Hardness           float64
# Solids             float64
# Chloramines        float64
# Sulfate            float64
# Conductivity       float64
# Organic_carbon     float64
# Trihalomethanes    float64
# Turbidity          float64
# dtype: object

# %% [markdown]
# ### 2.Examine the variables ‘Hardness’, ‘Sulfate’, and ‘Organic_carbon’ and comment on your observations.

# %%
freqgraph = data[['Hardness','Sulfate','Organic_carbon']]
freqgraph.hist(figsize=(20,10))
plt.show()

# %%
sns.pairplot(data=freqgraph)

# %%
sns.boxplot(data=freqgraph)
# Out:
# <AxesSubplot:>

# %% [markdown]
# from the first graph we can say that the data follows a normal distribution with some outliers, and also there is no significant correlation between the 3 features

# %% [markdown]
# ### 4. Carry out correlation analysis on the dataset and find the correlation factor between

# %%
corrmatrix=data.corr()
plt.subplots(figsize=(20,15))
sns.heatmap(corrmatrix, vmin=-.7,vmax=.7,linewidths=.2,annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# No two features in the data set are highly correlated

# %% [markdown]
# ### a. ph and Chloramines

# %%
data[['ph','Chloramines']].corr()
# Out:
#                    ph  Chloramines
# ph           1.000000    -0.024768
# Chloramines -0.024768     1.000000

# %%
sns.scatterplot(data=data,x=data['ph'], y=data['Chloramines'])
# Out:
# <AxesSubplot:xlabel='ph', ylabel='Chloramines'>

# %% [markdown]
# The correlation factor is -0.02468,approximated to 0 itself,thus we can conclude that there is no significant  corrrelation between ph and chloramines

# %% [markdown]
# ### b. ph and Conductivity

# %%
data[['ph','Conductivity']].corr()
# Out:
#                     ph  Conductivity
# ph            1.000000      0.014128
# Conductivity  0.014128      1.000000

# %%
sns.scatterplot(data=data,x=data['ph'], y=data['Conductivity'])
# Out:
# <AxesSubplot:xlabel='ph', ylabel='Conductivity'>

# %% [markdown]
# The correlation factor is 0.014128, which is also approximated to 0, so we can conclude that there is no significant correlation between ph and conductivity
